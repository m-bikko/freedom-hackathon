# %% [markdown]
# # Freedom Ticketon Hackathon - Enhanced Recommendation System
#
# This notebook implements a recommendation system for the Freedom Ticketon hackathon that incorporates:
# 1. User preferences for genres and event types
# 2. Temporal patterns (day of week preferences)
# 3. Attendance frequency patterns
# 4. City-based preferences
# 5. Popularity fallbacks

# %% [markdown]
# ## 1. Import Libraries

# %%
import pandas as pd
import numpy as np
from collections import Counter, defaultdict
from datetime import datetime
import matplotlib.pyplot as plt
import seaborn as sns
import sys  # For flushing stdout

try:
    from tqdm.notebook import tqdm
    has_tqdm = True
    print("tqdm imported successfully for progress bars")
except ImportError:
    has_tqdm = False
    print("tqdm not available, will use print statements for progress")

def cell_end():
    print("Cell ended!")
    sys.stdout.flush()
    
cell_end()
# Out:
# tqdm imported successfully for progress bars
# Cell ended!

# %% [markdown]
# ## 2. Define Evaluation Metrics

# %%
def apk(actual, predicted, k=10):
    if not actual:
        return 0.0
    if not predicted:
        return 0.0
    predicted = predicted[:k]
    score = 0.0
    num_hits = 0.0
    for i, p in enumerate(predicted):
        if p in actual and p not in predicted[:i]:
            num_hits += 1.0
            score += num_hits / (i + 1.0)
    return score / min(len(actual), k)

def mapk(y_true, y_pred, k=10):
    apk_scores = []
    for u in y_true:
        if u in y_pred:
            apk_scores.append(apk(y_true[u], y_pred[u], k))
        else:
            apk_scores.append(0.0)
    if not apk_scores:
        return 0.0
    return np.mean(apk_scores)

cell_end()
# Out:
# Cell ended!

# %% [markdown]
# ## 3. Load Data

# %%
print("Loading data...")
train_test = pd.read_csv('train_test.csv')
print(f"Loaded train_test.csv - Shape: {train_test.shape}")

events_description = pd.read_csv('events_description.csv')
print(f"Loaded events_description.csv - Shape: {events_description.shape}")

submission = pd.read_csv('submission.csv')
print(f"Loaded submission.csv - Shape: {submission.shape}")

cell_end()
# Out:
# Loading data...
# Loaded train_test.csv - Shape: (572032, 10)
# Loaded events_description.csv - Shape: (6028, 9)
# Loaded submission.csv - Shape: (53825, 2)
# Cell ended!

# %% [markdown]
# ## 4. Process Data

# %%
print("Processing data...")
train_test['reservation_time'] = pd.to_datetime(train_test['reservation_time'])
print("Converted timestamps to datetime")

paid_interactions = train_test[train_test['sale_status'] == 'PAID'].copy()
print(f"Filtered to {len(paid_interactions)} PAID interactions")

april_candidates = events_description[events_description['part_dataset'] == 'submission_movies']['item_id'].unique()
march_candidates = events_description[events_description['part_dataset'] == 'test']['item_id'].unique()

print(f"Found {len(april_candidates)} candidate events for April")
print(f"Found {len(march_candidates)} candidate events for March")

cell_end()
# Out:
# Processing data...
# Converted timestamps to datetime
# Filtered to 464253 PAID interactions
# Found 1033 candidate events for April
# Found 1023 candidate events for March
# Cell ended!

# %%
history_interactions = paid_interactions[paid_interactions['part_dataset'] == 'train'].copy()
print(f"History interactions (before March): {len(history_interactions)} rows")

march_true_interactions = paid_interactions[paid_interactions['part_dataset'] == 'test'].copy()
print(f"March interactions: {len(march_true_interactions)} rows")

full_history_interactions = paid_interactions[paid_interactions['part_dataset'].isin(['train', 'test'])].copy()
print(f"Full history: {len(full_history_interactions)} rows")

march_ground_truth = march_true_interactions.groupby('user_id')['item_id'].apply(list).to_dict()
print(f"Created ground truth for {len(march_ground_truth)} users in March")

history_with_details = pd.merge(history_interactions, events_description, on='item_id', how='left')
march_with_details = pd.merge(march_true_interactions, events_description, on='item_id', how='left')
full_history_with_details = pd.merge(full_history_interactions, events_description, on='item_id', how='left')
print("Merged interactions with event details")

cell_end()
# Out:
# History interactions (before March): 358551 rows
# March interactions: 105702 rows
# Full history: 464253 rows
# Created ground truth for 75127 users in March
# Merged interactions with event details
# Cell ended!

# %%
user_city = paid_interactions[['user_id', 'city']].drop_duplicates().set_index('user_id')['city'].to_dict()
print(f"Created city mapping for {len(user_city)} users")

user_gender = paid_interactions[['user_id', 'gender_main']].drop_duplicates().set_index('user_id')['gender_main'].to_dict()
print(f"Created gender mapping for {len(user_gender)} users")

user_age = paid_interactions[['user_id', 'age']].drop_duplicates().set_index('user_id')['age'].to_dict()
print(f"Created age mapping for {len(user_age)} users")

cell_end()
# Out:
# Created city mapping for 106587 users
# Created gender mapping for 106587 users
# Created age mapping for 106587 users
# Cell ended!

# %% [markdown]
# ## 5. Event and City Mappings

# %%
def get_event_city_mappings(df):
    """Extract city information for events from place_name and interactions"""
    event_city = {}
    event_place = {}
    
    for _, row in df.iterrows():
        item_id = row['item_id']
        city = row['city']
        place = row['place_name']
        
        # Store city and place information
        event_city[item_id] = city
        event_place[item_id] = place
    
    return event_city, event_place

event_city, event_place = get_event_city_mappings(paid_interactions)
print(f"Created city mapping for {len(event_city)} events")

event_genre = events_description[['item_id', 'film_genre']].drop_duplicates().set_index('item_id')['film_genre'].to_dict()
print(f"Created genre mapping for {len(event_genre)} events")

event_type = events_description[['item_id', 'film_type']].drop_duplicates().set_index('item_id')['film_type'].to_dict()
print(f"Created type mapping for {len(event_type)} events")

cell_end()
# Out:
# Created city mapping for 3972 events
# Created genre mapping for 4597 events
# Created type mapping for 4597 events
# Cell ended!

# %%
def calculate_popularity(interactions_df, candidate_events):
    """Calculate normalized popularity scores for candidate events"""
    event_counts = interactions_df['item_id'].value_counts().to_dict()
    total_interactions = sum(event_counts.values())
    
    if total_interactions > 0:
        popularity_scores = {event_id: event_counts.get(event_id, 0) / total_interactions 
                            for event_id in candidate_events}
    else:
        popularity_scores = {event_id: 0 for event_id in candidate_events}
    
    return popularity_scores

def calculate_city_popularity(interactions_df, candidate_events):
    """Calculate city-specific popularity scores for candidate events"""
    city_event_pop = {}
    
    for city in interactions_df['city'].unique():
        if pd.isna(city):
            continue
            
        city_data = interactions_df[interactions_df['city'] == city]
        city_counts = city_data['item_id'].value_counts().to_dict()
        total = sum(city_counts.values()) if city_counts else 0
        
        if total > 0:
            city_event_pop[city] = {event_id: city_counts.get(event_id, 0) / total 
                                    for event_id in candidate_events}
        else:
            city_event_pop[city] = {event_id: 0 for event_id in candidate_events}
    
    return city_event_pop

print("Calculating popularity scores...")
march_popularity = calculate_popularity(history_interactions, march_candidates)
print(f"Calculated popularity scores for {len(march_popularity)} March events")

april_popularity = calculate_popularity(full_history_interactions, april_candidates)
print(f"Calculated popularity scores for {len(april_popularity)} April events")

march_city_popularity = calculate_city_popularity(history_interactions, march_candidates)
print(f"Calculated city-specific popularity for March events in {len(march_city_popularity)} cities")

april_city_popularity = calculate_city_popularity(full_history_interactions, april_candidates)
print(f"Calculated city-specific popularity for April events in {len(april_city_popularity)} cities")

cell_end()
# Out:
# Calculating popularity scores...
# Calculated popularity scores for 1023 March events
# Calculated popularity scores for 1033 April events
# Calculated city-specific popularity for March events in 4 cities
# Calculated city-specific popularity for April events in 4 cities
# Cell ended!

# %% [markdown]
# ## 6. Temporal Pattern Extraction

# %%
print("Extracting temporal patterns...")
def extract_user_temporal_patterns(interactions_df):
    """
    Extract day of week preferences and attendance frequency for each user
    """
    print(f"Processing temporal patterns for {len(interactions_df)} interactions...")
    
    interactions_df['day_of_week'] = interactions_df['reservation_time'].dt.day_name()
    interactions_df['hour_of_day'] = interactions_df['reservation_time'].dt.hour
    interactions_df['month'] = interactions_df['reservation_time'].dt.month
    print("Added temporal columns")
    
    user_monthly_frequency = {}
    user_day_preferences = {}
    user_hour_preferences = {}
    
    total_users = len(interactions_df['user_id'].unique())
    print(f"Extracting patterns for {total_users} users...")
    
    for i, user_id in enumerate(interactions_df['user_id'].unique()):
        if i % 100 == 0 or i == total_users - 1:
            progress = (i + 1) / total_users * 100
            print(f"Processing users: {i+1}/{total_users} ({progress:.1f}%)", end="\r")
            sys.stdout.flush()
            
        user_data = interactions_df[interactions_df['user_id'] == user_id]
        
        if len(user_data) > 0:
            min_date = user_data['reservation_time'].min()
            max_date = user_data['reservation_time'].max()
            
            if pd.notna(min_date) and pd.notna(max_date):
                # Calculate months between first and last attendance
                months_active = ((max_date.year - min_date.year) * 12 + 
                                max_date.month - min_date.month + 1)
                
                if months_active > 0:
                    # Events per month
                    user_monthly_frequency[user_id] = len(user_data) / months_active
                else:
                    # All in one month
                    user_monthly_frequency[user_id] = len(user_data)
            else:
                user_monthly_frequency[user_id] = 0
        else:
            user_monthly_frequency[user_id] = 0
        
        # Calculate day of week preferences
        day_counts = user_data['day_of_week'].value_counts()
        total_days = day_counts.sum()
        
        if total_days > 0:
            user_day_preferences[user_id] = {day: count/total_days 
                                           for day, count in day_counts.items()}
        else:
            user_day_preferences[user_id] = {}
        
        hour_counts = user_data['hour_of_day'].value_counts()
        total_hours = hour_counts.sum()
        
        if total_hours > 0:
            user_hour_preferences[user_id] = {hour: count/total_hours 
                                            for hour, count in hour_counts.items()}
        else:
            user_hour_preferences[user_id] = {}
    
    print(f"\nCompleted temporal pattern extraction for {len(user_monthly_frequency)} users")
    return user_monthly_frequency, user_day_preferences, user_hour_preferences

cell_end()
# Out:
# Extracting temporal patterns...
# Cell ended!

# %%
def extract_event_temporal_patterns(interactions_df, candidate_events):
    """Extract day of week and hour patterns for events"""
    print(f"Extracting temporal patterns for {len(candidate_events)} events...")
    
    if 'day_of_week' not in interactions_df.columns:
        interactions_df['day_of_week'] = interactions_df['reservation_time'].dt.day_name()
    if 'hour_of_day' not in interactions_df.columns:
        interactions_df['hour_of_day'] = interactions_df['reservation_time'].dt.hour
    
    event_day_patterns = {}
    event_hour_patterns = {}
    
    total_events = len(candidate_events)
    for i, item_id in enumerate(candidate_events):
        if i % 100 == 0 or i == total_events - 1:
            progress = (i + 1) / total_events * 100
            print(f"Processing events: {i+1}/{total_events} ({progress:.1f}%)", end="\r")
            sys.stdout.flush()
            
        item_data = interactions_df[interactions_df['item_id'] == item_id]
        
        if not item_data.empty:
            day_counts = item_data['day_of_week'].value_counts()
            total_days = day_counts.sum()
            
            if total_days > 0:
                event_day_patterns[item_id] = {day: count/total_days 
                                             for day, count in day_counts.items()}
            else:
                event_day_patterns[item_id] = {}
            
            hour_counts = item_data['hour_of_day'].value_counts()
            total_hours = hour_counts.sum()
            
            if total_hours > 0:
                event_hour_patterns[item_id] = {hour: count/total_hours 
                                              for hour, count in hour_counts.items()}
            else:
                event_hour_patterns[item_id] = {}
        else:
            event_day_patterns[item_id] = {}
            event_hour_patterns[item_id] = {}
    
    print(f"\nExtracted temporal patterns for {len(event_day_patterns)} events")
    return event_day_patterns, event_hour_patterns

cell_end()
# Out:
# Cell ended!

# %%
# Extract temporal patterns
print("Extracting user temporal patterns...")
history_frequency, history_day_prefs, history_hour_prefs = extract_user_temporal_patterns(history_interactions)
print(f"Extracted frequency data for {len(history_frequency)} users from history data")

full_frequency, full_day_prefs, full_hour_prefs = extract_user_temporal_patterns(full_history_interactions)
print(f"Extracted frequency data for {len(full_frequency)} users from full history")

print("Extracting event temporal patterns...")
march_day_patterns, march_hour_patterns = extract_event_temporal_patterns(
    history_interactions, march_candidates)
print(f"Extracted day patterns for {len(march_day_patterns)} March events")

april_day_patterns, april_hour_patterns = extract_event_temporal_patterns(
    full_history_interactions, april_candidates)
print(f"Extracted day patterns for {len(april_day_patterns)} April events")

cell_end()
# Out:
# Extracting user temporal patterns...
# Processing temporal patterns for 358551 interactions...
# Added temporal columns
# Extracting patterns for 102098 users...
# Processing users: 102098/102098 (100.0%)
# Completed temporal pattern extraction for 102098 users
# Extracted frequency data for 102098 users from history data
# Processing temporal patterns for 464253 interactions...
# Added temporal columns
# Extracting patterns for 106587 users...
# Processing users: 106587/106587 (100.0%)
# Completed temporal pattern extraction for 106587 users
# Extracted frequency data for 106587 users from full history
# Extracting event temporal patterns...
# Extracting temporal patterns for 1023 events...
# Processing events: 1023/1023 (100.0%)
# Extracted temporal patterns for 1023 events
# Extracted day patterns for 1023 March events
# Extracting temporal patterns for 1033 events...
# Processing events: 1033/1033 (100.0%)
# Extracted temporal patterns for 1033 events
# Extracted day patterns for 1033 April events
# Cell ended!

# %% [markdown]
# ## 7. User Preference Analysis

# %%
print("Analyzing user preferences...")
def get_user_preferences(user_id, interactions_df):
    """Get top genre and type preferences for a user"""
    user_data = interactions_df[interactions_df['user_id'] == user_id]
    
    if user_data.empty:
        return [], []
    
    genre_counts = Counter()
    for _, row in user_data.iterrows():
        item_id = row['item_id']
        if item_id in event_genre and pd.notna(event_genre[item_id]):
            genre_counts[event_genre[item_id]] += 1
    
    type_counts = Counter()
    for _, row in user_data.iterrows():
        item_id = row['item_id']
        if item_id in event_type and pd.notna(event_type[item_id]):
            type_counts[event_type[item_id]] += 1
    
    top_genres = [genre for genre, _ in genre_counts.most_common(3)]
    top_types = [t_type for t_type, _ in type_counts.most_common(2)]
    
    return top_genres, top_types

cell_end()
# Out:
# Analyzing user preferences...
# Cell ended!

# %% [markdown]
# ## 8. Visualization Functions

# %%
def plot_day_preferences():
    """Create plot of aggregate day preferences"""
    plt.figure(figsize=(10, 6))
    
    all_days = defaultdict(float)
    for user_days in full_day_prefs.values():
        for day, weight in user_days.items():
            all_days[day] += weight
    
    days_order = ['Monday', 'Tuesday', 'Wednesday', 'Thursday', 'Friday', 'Saturday', 'Sunday']
    day_series = pd.Series({day: all_days.get(day, 0) for day in days_order})
    day_series = day_series / day_series.sum()  # Normalize
    
    ax = day_series.plot(kind='bar', color='skyblue')
    plt.title('User Day of Week Preferences')
    plt.xlabel('Day of Week')
    plt.ylabel('Normalized Preference')
    plt.xticks(rotation=45)
    plt.tight_layout()
    plt.savefig('day_preferences.png')
    plt.close()
    return plt

def plot_user_frequency():
    """Plot distribution of user attendance frequency"""
    plt.figure(figsize=(10, 6))
    
    freq_series = pd.Series(full_frequency)
    freq_series = freq_series[freq_series > 0]  # Filter out zeros
    
    plt.hist(freq_series, bins=20, color='green', alpha=0.7)
    plt.title('Distribution of User Event Attendance Frequency')
    plt.xlabel('Events per Month')
    plt.ylabel('Number of Users')
    plt.tight_layout()
    plt.savefig('user_frequency.png')
    plt.close()
    return plt

# Generate plots
try:
    print("Generating visualizations...")
    plot_day_preferences()
    plot_user_frequency()
    print("Created visualizations: day_preferences.png and user_frequency.png")
except Exception as e:
    print(f"Error generating plots: {e}")

cell_end()
# Out:
# Generating visualizations...
# Created visualizations: day_preferences.png and user_frequency.png
# Cell ended!

# %% [markdown]
# ## 9. Recommendation Model

# %%
print("Building recommendation model...")
def generate_recommendations(target_user, history_data, candidate_events, 
                           popularity_scores, city_popularity,
                           user_frequency, user_day_prefs, 
                           event_day_patterns,
                           debug=False):  # Add debug parameter for tracking
    """
    Generate recommendations for a user based on preferences, 
    frequency patterns, and day of week preferences
    """
    user_city_val = user_city.get(target_user)
    top_genres, top_types = get_user_preferences(target_user, history_data)
    
    monthly_frequency = user_frequency.get(target_user, 0)
    day_preferences = user_day_prefs.get(target_user, {})
    
    # Debug output
    if debug:
        print(f"Debug for user {target_user}:")
        print(f"  City: {user_city_val}")
        print(f"  Top genres: {top_genres}")
        print(f"  Top types: {top_types}")
        print(f"  Monthly frequency: {monthly_frequency:.2f}")
        print(f"  Day preferences: {day_preferences}")
    
    # Initialize scores
    event_scores = {}
    
    for event_id in candidate_events:
        score = 0
        event_city_val = event_city.get(event_id)
        event_genre_val = event_genre.get(event_id)
        event_type_val = event_type.get(event_id)
        event_day_pattern = event_day_patterns.get(event_id, {})
        
        # 1. Primary boost - genre and type match in user's city
        if user_city_val and event_city_val and user_city_val == event_city_val:
            if event_genre_val and event_genre_val in top_genres:
                score += 6
            if event_type_val and event_type_val in top_types:
                score += 4 
        
        # 2. Secondary boost - genre and type match in any city
        else:
            if event_genre_val and event_genre_val in top_genres:
                score += 3
            if event_type_val and event_type_val in top_types:
                score += 2
        
        # 3. Day of week preference boost
        day_match_score = 0
        for day, user_pref in day_preferences.items():
            if day in event_day_pattern:
                day_match_score += user_pref * event_day_pattern[day]
        
        score += day_match_score * 2
        
        # 4. Frequency-based adjustments
        if monthly_frequency > 0:
            if monthly_frequency > 3:  # High frequency users (>3/month)
                score = score * 1.2  # Boost preference matching
                score += popularity_scores.get(event_id, 0) * 0.1
            elif monthly_frequency > 1:  # Medium frequency (1-3/month)
                score += popularity_scores.get(event_id, 0) * 0.3
            else:  # Low frequency (<1/month)
                score += popularity_scores.get(event_id, 0) * 0.7
        else:
            # 5. Cold start - rely on popularity
            if user_city_val and event_city_val and user_city_val == event_city_val:
                city_pop = city_popularity.get(user_city_val, {}).get(event_id, 0)
                score += city_pop * 3
            else:
                score += popularity_scores.get(event_id, 0) * 1.5
        
        event_scores[event_id] = score
    
    sorted_events = sorted(event_scores.items(), key=lambda x: x[1], reverse=True)
    top_events = [event_id for event_id, _ in sorted_events[:10]]
    
    if debug:
        print("  Top 3 recommended events:")
        for event_id, score in sorted_events[:3]:
            print(f"    {event_id}: {score:.4f} (Genre: {event_genre.get(event_id)}, Type: {event_type.get(event_id)})")
    
    return top_events

cell_end()
# Out:
# Building recommendation model...
# Cell ended!

# %% [markdown]
# ## 10. March Validation

# %%
print("Validating on March data...")

march_predictions = {}
march_users = march_true_interactions['user_id'].unique()

print(f"Generating recommendations for {len(march_users)} users in March...")

debug_users = march_users[:3]  # Debug first 3 users

total_users = len(march_users)
for i, user in enumerate(march_users):
    if i % 100 == 0 or i == total_users - 1:
        progress = (i + 1) / total_users * 100
        print(f"Progress: {i+1}/{total_users} users processed ({progress:.1f}%)")
        sys.stdout.flush()
        
    try:
        # Enable debug for sample users
        debug_mode = user in debug_users
        
        recommendations = generate_recommendations(
            user,
            history_with_details,
            march_candidates,
            march_popularity,
            march_city_popularity,
            history_frequency,
            history_day_prefs,
            march_day_patterns,
            debug=debug_mode
        )
        march_predictions[user] = recommendations
    except Exception as e:
        print(f"Error for user {user}: {e}")
        march_predictions[user] = []

print(f"Completed generating recommendations for {len(march_predictions)} March users")

print("Calculating MAP@10 score...")
march_map = mapk(march_ground_truth, march_predictions, 10)
print(f"MAP@10 score for March validation: {march_map}")

cell_end()
# Out:
# Validating on March data...
# Generating recommendations for 75127 users in March...
# Progress: 1/75127 users processed (0.0%)
# Debug for user user_45087:
#   City: Шымкент
#   Top genres: ['комедия', 'комедия/семейный', '\nкомедия']
#   Top types: ['film']
#   Monthly frequency: 0.30
#   Day preferences: {'Wednesday': np.float64(0.3333333333333333), 'Tuesday': np.float64(0.3333333333333333), 'Sunday': np.float64(0.3333333333333333)}
#   Top 3 recommended events:
#     event_4425: 10.2517 (Genre: комедия, Type: film)
#     event_1720: 6.2541 (Genre: комедия, Type: performance)
#     event_2548: 6.0000 (Genre: комедия, Type: performance)
# Debug for user user_21325:
#   City: Астана
#   Top genres: ['комедия', 'Драма/комедия']
#   Top types: ['film']
#   Monthly frequency: 0.83
#   Day preferences: {'Saturday': np.float64(0.2), 'Friday': np.float64(0.2), 'Thursday': np.float64(0.2), 'Sunday': np.float64(0.2), 'Monday': np.float64(0.2)}
#   Top 3 recommended events:
#     event_751: 6.2872 (Genre: комедия, Type: performance)
#     event_338: 6.2808 (Genre: комедия, Type: performance)
#     event_71: 6.2748 (Genre: комедия, Type: performance)
# Debug for user user_24231:
#   City: Астана
#   Top genres: ['концерт']
#   Top types: ['concert']
#   Monthly frequency: 2.00
#   Day preferences: {'Monday': np.float64(1.0)}
#   Top 3 recommended events:
#     event_3111: 11.0000 (Genre: концерт, Type: concert)
#     event_3644: 10.5714 (Genre: концерт, Type: concert)
#     event_4240: 10.4849 (Genre: концерт, Type: concert)
# Progress: 101/75127 users processed (0.1%)
# Progress: 201/75127 users processed (0.3%)
# Progress: 301/75127 users processed (0.4%)
# Progress: 401/75127 users processed (0.5%)
# Progress: 501/75127 users processed (0.7%)
# Progress: 601/75127 users processed (0.8%)
# Progress: 701/75127 users processed (0.9%)
# Progress: 801/75127 users processed (1.1%)
# Progress: 901/75127 users processed (1.2%)
# Progress: 1001/75127 users processed (1.3%)
# Progress: 1101/75127 users processed (1.5%)
# Progress: 1201/75127 users processed (1.6%)
# Progress: 1301/75127 users processed (1.7%)
# Progress: 1401/75127 users processed (1.9%)
# Progress: 1501/75127 users processed (2.0%)
# Progress: 1601/75127 users processed (2.1%)
# Progress: 1701/75127 users processed (2.3%)
# Progress: 1801/75127 users processed (2.4%)
# Progress: 1901/75127 users processed (2.5%)
# Progress: 2001/75127 users processed (2.7%)
# Progress: 2101/75127 users processed (2.8%)
# Progress: 2201/75127 users processed (2.9%)
# Progress: 2301/75127 users processed (3.1%)
# Progress: 2401/75127 users processed (3.2%)
# Progress: 2501/75127 users processed (3.3%)
# Progress: 2601/75127 users processed (3.5%)
# Progress: 2701/75127 users processed (3.6%)
# Progress: 2801/75127 users processed (3.7%)
# Progress: 2901/75127 users processed (3.9%)
# Progress: 3001/75127 users processed (4.0%)
# Progress: 3101/75127 users processed (4.1%)
# Progress: 3201/75127 users processed (4.3%)
# Progress: 3301/75127 users processed (4.4%)
# Progress: 3401/75127 users processed (4.5%)
# Progress: 3501/75127 users processed (4.7%)
# Progress: 3601/75127 users processed (4.8%)
# Progress: 3701/75127 users processed (4.9%)
# Progress: 3801/75127 users processed (5.1%)
# Progress: 3901/75127 users processed (5.2%)
# Progress: 4001/75127 users processed (5.3%)
# Progress: 4101/75127 users processed (5.5%)
# Progress: 4201/75127 users processed (5.6%)
# Progress: 4301/75127 users processed (5.7%)
# Progress: 4401/75127 users processed (5.9%)
# Progress: 4501/75127 users processed (6.0%)
# Progress: 4601/75127 users processed (6.1%)
# Progress: 4701/75127 users processed (6.3%)
# Progress: 4801/75127 users processed (6.4%)
# Progress: 4901/75127 users processed (6.5%)
# Progress: 5001/75127 users processed (6.7%)
# Progress: 5101/75127 users processed (6.8%)
# Progress: 5201/75127 users processed (6.9%)
# Progress: 5301/75127 users processed (7.1%)
# Progress: 5401/75127 users processed (7.2%)
# Progress: 5501/75127 users processed (7.3%)
# Progress: 5601/75127 users processed (7.5%)
# Progress: 5701/75127 users processed (7.6%)
# Progress: 5801/75127 users processed (7.7%)
# Progress: 5901/75127 users processed (7.9%)
# Progress: 6001/75127 users processed (8.0%)
# Progress: 6101/75127 users processed (8.1%)
# Progress: 6201/75127 users processed (8.3%)
# Progress: 6301/75127 users processed (8.4%)
# Progress: 6401/75127 users processed (8.5%)
# Progress: 6501/75127 users processed (8.7%)
# Progress: 6601/75127 users processed (8.8%)
# Progress: 6701/75127 users processed (8.9%)
# Progress: 6801/75127 users processed (9.1%)
# Progress: 6901/75127 users processed (9.2%)
# Progress: 7001/75127 users processed (9.3%)
# Progress: 7101/75127 users processed (9.5%)
# Progress: 7201/75127 users processed (9.6%)
# Progress: 7301/75127 users processed (9.7%)
# Progress: 7401/75127 users processed (9.9%)
# Progress: 7501/75127 users processed (10.0%)
# Progress: 7601/75127 users processed (10.1%)
# Progress: 7701/75127 users processed (10.3%)
# Progress: 7801/75127 users processed (10.4%)
# Progress: 7901/75127 users processed (10.5%)
# Progress: 8001/75127 users processed (10.6%)
# Progress: 8101/75127 users processed (10.8%)
# Progress: 8201/75127 users processed (10.9%)
# Progress: 8301/75127 users processed (11.0%)
# Progress: 8401/75127 users processed (11.2%)
# Progress: 8501/75127 users processed (11.3%)
# Progress: 8601/75127 users processed (11.4%)
# Progress: 8701/75127 users processed (11.6%)
# Progress: 8801/75127 users processed (11.7%)
# Progress: 8901/75127 users processed (11.8%)
# Progress: 9001/75127 users processed (12.0%)
# Progress: 9101/75127 users processed (12.1%)
# Progress: 9201/75127 users processed (12.2%)
# Progress: 9301/75127 users processed (12.4%)
# Progress: 9401/75127 users processed (12.5%)
# Progress: 9501/75127 users processed (12.6%)
# Progress: 9601/75127 users processed (12.8%)
# Progress: 9701/75127 users processed (12.9%)
# Progress: 9801/75127 users processed (13.0%)
# Progress: 9901/75127 users processed (13.2%)
# Progress: 10001/75127 users processed (13.3%)
# Progress: 10101/75127 users processed (13.4%)
# Progress: 10201/75127 users processed (13.6%)
# Progress: 10301/75127 users processed (13.7%)
# Progress: 10401/75127 users processed (13.8%)
# Progress: 10501/75127 users processed (14.0%)
# Progress: 10601/75127 users processed (14.1%)
# Progress: 10701/75127 users processed (14.2%)
# Progress: 10801/75127 users processed (14.4%)
# Progress: 10901/75127 users processed (14.5%)
# Progress: 11001/75127 users processed (14.6%)
# Progress: 11101/75127 users processed (14.8%)
# Progress: 11201/75127 users processed (14.9%)
# Progress: 11301/75127 users processed (15.0%)
# Progress: 11401/75127 users processed (15.2%)
# Progress: 11501/75127 users processed (15.3%)
# Progress: 11601/75127 users processed (15.4%)
# Progress: 11701/75127 users processed (15.6%)
# Progress: 11801/75127 users processed (15.7%)
# Progress: 11901/75127 users processed (15.8%)
# Progress: 12001/75127 users processed (16.0%)
# Progress: 12101/75127 users processed (16.1%)
# Progress: 12201/75127 users processed (16.2%)
# Progress: 12301/75127 users processed (16.4%)
# Progress: 12401/75127 users processed (16.5%)
# Progress: 12501/75127 users processed (16.6%)
# Progress: 12601/75127 users processed (16.8%)
# Progress: 12701/75127 users processed (16.9%)
# Progress: 12801/75127 users processed (17.0%)
# Progress: 12901/75127 users processed (17.2%)
# Progress: 13001/75127 users processed (17.3%)
# Progress: 13101/75127 users processed (17.4%)
# Progress: 13201/75127 users processed (17.6%)
# Progress: 13301/75127 users processed (17.7%)
# Progress: 13401/75127 users processed (17.8%)
# Progress: 13501/75127 users processed (18.0%)
# Progress: 13601/75127 users processed (18.1%)
# Progress: 13701/75127 users processed (18.2%)
# Progress: 13801/75127 users processed (18.4%)
# Progress: 13901/75127 users processed (18.5%)
# Progress: 14001/75127 users processed (18.6%)
# Progress: 14101/75127 users processed (18.8%)
# Progress: 14201/75127 users processed (18.9%)
# Progress: 14301/75127 users processed (19.0%)
# Progress: 14401/75127 users processed (19.2%)
# Progress: 14501/75127 users processed (19.3%)
# Progress: 14601/75127 users processed (19.4%)
# Progress: 14701/75127 users processed (19.6%)
# Progress: 14801/75127 users processed (19.7%)
# Progress: 14901/75127 users processed (19.8%)
# Progress: 15001/75127 users processed (20.0%)
# Progress: 15101/75127 users processed (20.1%)
# Progress: 15201/75127 users processed (20.2%)
# Progress: 15301/75127 users processed (20.4%)
# Progress: 15401/75127 users processed (20.5%)
# Progress: 15501/75127 users processed (20.6%)
# Progress: 15601/75127 users processed (20.8%)
# Progress: 15701/75127 users processed (20.9%)
# Progress: 15801/75127 users processed (21.0%)
# Progress: 15901/75127 users processed (21.2%)
# Progress: 16001/75127 users processed (21.3%)
# Progress: 16101/75127 users processed (21.4%)
# Progress: 16201/75127 users processed (21.6%)
# Progress: 16301/75127 users processed (21.7%)
# Progress: 16401/75127 users processed (21.8%)
# Progress: 16501/75127 users processed (22.0%)
# Progress: 16601/75127 users processed (22.1%)
# Progress: 16701/75127 users processed (22.2%)
# Progress: 16801/75127 users processed (22.4%)
# Progress: 16901/75127 users processed (22.5%)
# Progress: 17001/75127 users processed (22.6%)
# Progress: 17101/75127 users processed (22.8%)
# Progress: 17201/75127 users processed (22.9%)
# Progress: 17301/75127 users processed (23.0%)
# Progress: 17401/75127 users processed (23.2%)
# Progress: 17501/75127 users processed (23.3%)
# Progress: 17601/75127 users processed (23.4%)
# Progress: 17701/75127 users processed (23.6%)
# Progress: 17801/75127 users processed (23.7%)
# Progress: 17901/75127 users processed (23.8%)
# Progress: 18001/75127 users processed (24.0%)
# Progress: 18101/75127 users processed (24.1%)
# Progress: 18201/75127 users processed (24.2%)
# Progress: 18301/75127 users processed (24.4%)
# Progress: 18401/75127 users processed (24.5%)
# Progress: 18501/75127 users processed (24.6%)
# Progress: 18601/75127 users processed (24.8%)
# Progress: 18701/75127 users processed (24.9%)
# Progress: 18801/75127 users processed (25.0%)
# Progress: 18901/75127 users processed (25.2%)
# Progress: 19001/75127 users processed (25.3%)
# Progress: 19101/75127 users processed (25.4%)
# Progress: 19201/75127 users processed (25.6%)
# Progress: 19301/75127 users processed (25.7%)
# Progress: 19401/75127 users processed (25.8%)
# Progress: 19501/75127 users processed (26.0%)
# Progress: 19601/75127 users processed (26.1%)
# Progress: 19701/75127 users processed (26.2%)
# Progress: 19801/75127 users processed (26.4%)
# Progress: 19901/75127 users processed (26.5%)
# Progress: 20001/75127 users processed (26.6%)
# Progress: 20101/75127 users processed (26.8%)
# Progress: 20201/75127 users processed (26.9%)
# Progress: 20301/75127 users processed (27.0%)
# Progress: 20401/75127 users processed (27.2%)
# Progress: 20501/75127 users processed (27.3%)
# Progress: 20601/75127 users processed (27.4%)
# Progress: 20701/75127 users processed (27.6%)
# Progress: 20801/75127 users processed (27.7%)
# Progress: 20901/75127 users processed (27.8%)
# Progress: 21001/75127 users processed (28.0%)
# Progress: 21101/75127 users processed (28.1%)
# Progress: 21201/75127 users processed (28.2%)
# Progress: 21301/75127 users processed (28.4%)
# Progress: 21401/75127 users processed (28.5%)
# Progress: 21501/75127 users processed (28.6%)
# Progress: 21601/75127 users processed (28.8%)
# Progress: 21701/75127 users processed (28.9%)
# Progress: 21801/75127 users processed (29.0%)
# Progress: 21901/75127 users processed (29.2%)
# Progress: 22001/75127 users processed (29.3%)
# Progress: 22101/75127 users processed (29.4%)
# Progress: 22201/75127 users processed (29.6%)
# Progress: 22301/75127 users processed (29.7%)
# Progress: 22401/75127 users processed (29.8%)
# Progress: 22501/75127 users processed (30.0%)
# Progress: 22601/75127 users processed (30.1%)
# Progress: 22701/75127 users processed (30.2%)
# Progress: 22801/75127 users processed (30.3%)
# Progress: 22901/75127 users processed (30.5%)
# Progress: 23001/75127 users processed (30.6%)
# Progress: 23101/75127 users processed (30.7%)
# Progress: 23201/75127 users processed (30.9%)
# Progress: 23301/75127 users processed (31.0%)
# Progress: 23401/75127 users processed (31.1%)
# Progress: 23501/75127 users processed (31.3%)
# Progress: 23601/75127 users processed (31.4%)
# Progress: 23701/75127 users processed (31.5%)
# Progress: 23801/75127 users processed (31.7%)
# Progress: 23901/75127 users processed (31.8%)
# Progress: 24001/75127 users processed (31.9%)
# Progress: 24101/75127 users processed (32.1%)
# Progress: 24201/75127 users processed (32.2%)
# Progress: 24301/75127 users processed (32.3%)
# Progress: 24401/75127 users processed (32.5%)
# Progress: 24501/75127 users processed (32.6%)
# Progress: 24601/75127 users processed (32.7%)
# Progress: 24701/75127 users processed (32.9%)
# Progress: 24801/75127 users processed (33.0%)
# Progress: 24901/75127 users processed (33.1%)
# Progress: 25001/75127 users processed (33.3%)
# Progress: 25101/75127 users processed (33.4%)
# Progress: 25201/75127 users processed (33.5%)
# Progress: 25301/75127 users processed (33.7%)
# Progress: 25401/75127 users processed (33.8%)
# Progress: 25501/75127 users processed (33.9%)
# Progress: 25601/75127 users processed (34.1%)
# Progress: 25701/75127 users processed (34.2%)
# Progress: 25801/75127 users processed (34.3%)
# Progress: 25901/75127 users processed (34.5%)
# Progress: 26001/75127 users processed (34.6%)
# Progress: 26101/75127 users processed (34.7%)
# Progress: 26201/75127 users processed (34.9%)
# Progress: 26301/75127 users processed (35.0%)
# Progress: 26401/75127 users processed (35.1%)
# Progress: 26501/75127 users processed (35.3%)
# Progress: 26601/75127 users processed (35.4%)
# Progress: 26701/75127 users processed (35.5%)
# Progress: 26801/75127 users processed (35.7%)
# Progress: 26901/75127 users processed (35.8%)
# Progress: 27001/75127 users processed (35.9%)
# Progress: 27101/75127 users processed (36.1%)
# Progress: 27201/75127 users processed (36.2%)
# Progress: 27301/75127 users processed (36.3%)
# Progress: 27401/75127 users processed (36.5%)
# Progress: 27501/75127 users processed (36.6%)
# Progress: 27601/75127 users processed (36.7%)
# Progress: 27701/75127 users processed (36.9%)
# Progress: 27801/75127 users processed (37.0%)
# Progress: 27901/75127 users processed (37.1%)
# Progress: 28001/75127 users processed (37.3%)
# Progress: 28101/75127 users processed (37.4%)
# Progress: 28201/75127 users processed (37.5%)
# Progress: 28301/75127 users processed (37.7%)
# Progress: 28401/75127 users processed (37.8%)
# Progress: 28501/75127 users processed (37.9%)
# Progress: 28601/75127 users processed (38.1%)
# Progress: 28701/75127 users processed (38.2%)
# Progress: 28801/75127 users processed (38.3%)
# Progress: 28901/75127 users processed (38.5%)
# Progress: 29001/75127 users processed (38.6%)
# Progress: 29101/75127 users processed (38.7%)
# Progress: 29201/75127 users processed (38.9%)
# Progress: 29301/75127 users processed (39.0%)
# Progress: 29401/75127 users processed (39.1%)
# Progress: 29501/75127 users processed (39.3%)
# Progress: 29601/75127 users processed (39.4%)
# Progress: 29701/75127 users processed (39.5%)
# Progress: 29801/75127 users processed (39.7%)
# Progress: 29901/75127 users processed (39.8%)
# Progress: 30001/75127 users processed (39.9%)
# Progress: 30101/75127 users processed (40.1%)
# Progress: 30201/75127 users processed (40.2%)
# Progress: 30301/75127 users processed (40.3%)
# Progress: 30401/75127 users processed (40.5%)
# Progress: 30501/75127 users processed (40.6%)
# Progress: 30601/75127 users processed (40.7%)
# Progress: 30701/75127 users processed (40.9%)
# Progress: 30801/75127 users processed (41.0%)
# Progress: 30901/75127 users processed (41.1%)
# Progress: 31001/75127 users processed (41.3%)
# Progress: 31101/75127 users processed (41.4%)
# Progress: 31201/75127 users processed (41.5%)
# Progress: 31301/75127 users processed (41.7%)
# Progress: 31401/75127 users processed (41.8%)
# Progress: 31501/75127 users processed (41.9%)
# Progress: 31601/75127 users processed (42.1%)
# Progress: 31701/75127 users processed (42.2%)
# Progress: 31801/75127 users processed (42.3%)
# Progress: 31901/75127 users processed (42.5%)
# Progress: 32001/75127 users processed (42.6%)
# Progress: 32101/75127 users processed (42.7%)
# Progress: 32201/75127 users processed (42.9%)
# Progress: 32301/75127 users processed (43.0%)
# Progress: 32401/75127 users processed (43.1%)
# Progress: 32501/75127 users processed (43.3%)
# Progress: 32601/75127 users processed (43.4%)
# Progress: 32701/75127 users processed (43.5%)
# Progress: 32801/75127 users processed (43.7%)
# Progress: 32901/75127 users processed (43.8%)
# Progress: 33001/75127 users processed (43.9%)
# Progress: 33101/75127 users processed (44.1%)
# Progress: 33201/75127 users processed (44.2%)
# Progress: 33301/75127 users processed (44.3%)
# Progress: 33401/75127 users processed (44.5%)
# Progress: 33501/75127 users processed (44.6%)
# Progress: 33601/75127 users processed (44.7%)
# Progress: 33701/75127 users processed (44.9%)
# Progress: 33801/75127 users processed (45.0%)
# Progress: 33901/75127 users processed (45.1%)
# Progress: 34001/75127 users processed (45.3%)
# Progress: 34101/75127 users processed (45.4%)
# Progress: 34201/75127 users processed (45.5%)
# Progress: 34301/75127 users processed (45.7%)
# Progress: 34401/75127 users processed (45.8%)
# Progress: 34501/75127 users processed (45.9%)
# Progress: 34601/75127 users processed (46.1%)
# Progress: 34701/75127 users processed (46.2%)
# Progress: 34801/75127 users processed (46.3%)
# Progress: 34901/75127 users processed (46.5%)
# Progress: 35001/75127 users processed (46.6%)
# Progress: 35101/75127 users processed (46.7%)
# Progress: 35201/75127 users processed (46.9%)
# Progress: 35301/75127 users processed (47.0%)
# Progress: 35401/75127 users processed (47.1%)
# Progress: 35501/75127 users processed (47.3%)
# Progress: 35601/75127 users processed (47.4%)
# Progress: 35701/75127 users processed (47.5%)
# Progress: 35801/75127 users processed (47.7%)
# Progress: 35901/75127 users processed (47.8%)
# Progress: 36001/75127 users processed (47.9%)
# Progress: 36101/75127 users processed (48.1%)
# Progress: 36201/75127 users processed (48.2%)
# Progress: 36301/75127 users processed (48.3%)
# Progress: 36401/75127 users processed (48.5%)
# Progress: 36501/75127 users processed (48.6%)
# Progress: 36601/75127 users processed (48.7%)
# Progress: 36701/75127 users processed (48.9%)
# Progress: 36801/75127 users processed (49.0%)
# Progress: 36901/75127 users processed (49.1%)
# Progress: 37001/75127 users processed (49.3%)
# Progress: 37101/75127 users processed (49.4%)
# Progress: 37201/75127 users processed (49.5%)
# Progress: 37301/75127 users processed (49.7%)
# Progress: 37401/75127 users processed (49.8%)
# Progress: 37501/75127 users processed (49.9%)
# Progress: 37601/75127 users processed (50.0%)
# Progress: 37701/75127 users processed (50.2%)
# Progress: 37801/75127 users processed (50.3%)
# Progress: 37901/75127 users processed (50.4%)
# Progress: 38001/75127 users processed (50.6%)
# Progress: 38101/75127 users processed (50.7%)
# Progress: 38201/75127 users processed (50.8%)
# Progress: 38301/75127 users processed (51.0%)
# Progress: 38401/75127 users processed (51.1%)
# Progress: 38501/75127 users processed (51.2%)
# Progress: 38601/75127 users processed (51.4%)
# Progress: 38701/75127 users processed (51.5%)
# Progress: 38801/75127 users processed (51.6%)
# Progress: 38901/75127 users processed (51.8%)
# Progress: 39001/75127 users processed (51.9%)
# Progress: 39101/75127 users processed (52.0%)
# Progress: 39201/75127 users processed (52.2%)
# Progress: 39301/75127 users processed (52.3%)
# Progress: 39401/75127 users processed (52.4%)
# Progress: 39501/75127 users processed (52.6%)
# Progress: 39601/75127 users processed (52.7%)
# Progress: 39701/75127 users processed (52.8%)
# Progress: 39801/75127 users processed (53.0%)
# Progress: 39901/75127 users processed (53.1%)
# Progress: 40001/75127 users processed (53.2%)
# Progress: 40101/75127 users processed (53.4%)
# Progress: 40201/75127 users processed (53.5%)
# Progress: 40301/75127 users processed (53.6%)
# Progress: 40401/75127 users processed (53.8%)
# Progress: 40501/75127 users processed (53.9%)
# Progress: 40601/75127 users processed (54.0%)
# Progress: 40701/75127 users processed (54.2%)
# Progress: 40801/75127 users processed (54.3%)
# Progress: 40901/75127 users processed (54.4%)
# Progress: 41001/75127 users processed (54.6%)
# Progress: 41101/75127 users processed (54.7%)
# Progress: 41201/75127 users processed (54.8%)
# Progress: 41301/75127 users processed (55.0%)
# Progress: 41401/75127 users processed (55.1%)
# Progress: 41501/75127 users processed (55.2%)
# Progress: 41601/75127 users processed (55.4%)
# Progress: 41701/75127 users processed (55.5%)
# Progress: 41801/75127 users processed (55.6%)
# Progress: 41901/75127 users processed (55.8%)
# Progress: 42001/75127 users processed (55.9%)
# Progress: 42101/75127 users processed (56.0%)
# Progress: 42201/75127 users processed (56.2%)
# Progress: 42301/75127 users processed (56.3%)
# Progress: 42401/75127 users processed (56.4%)
# Progress: 42501/75127 users processed (56.6%)
# Progress: 42601/75127 users processed (56.7%)
# Progress: 42701/75127 users processed (56.8%)
# Progress: 42801/75127 users processed (57.0%)
# Progress: 42901/75127 users processed (57.1%)
# Progress: 43001/75127 users processed (57.2%)
# Progress: 43101/75127 users processed (57.4%)
# Progress: 43201/75127 users processed (57.5%)
# Progress: 43301/75127 users processed (57.6%)
# Progress: 43401/75127 users processed (57.8%)
# Progress: 43501/75127 users processed (57.9%)
# Progress: 43601/75127 users processed (58.0%)
# Progress: 43701/75127 users processed (58.2%)
# Progress: 43801/75127 users processed (58.3%)
# Progress: 43901/75127 users processed (58.4%)
# Progress: 44001/75127 users processed (58.6%)
# Progress: 44101/75127 users processed (58.7%)
# Progress: 44201/75127 users processed (58.8%)
# Progress: 44301/75127 users processed (59.0%)
# Progress: 44401/75127 users processed (59.1%)
# Progress: 44501/75127 users processed (59.2%)
# Progress: 44601/75127 users processed (59.4%)
# Progress: 44701/75127 users processed (59.5%)
# Progress: 44801/75127 users processed (59.6%)
# Progress: 44901/75127 users processed (59.8%)
# Progress: 45001/75127 users processed (59.9%)
# Progress: 45101/75127 users processed (60.0%)
# Progress: 45201/75127 users processed (60.2%)
# Progress: 45301/75127 users processed (60.3%)
# Progress: 45401/75127 users processed (60.4%)
# Progress: 45501/75127 users processed (60.6%)
# Progress: 45601/75127 users processed (60.7%)
# Progress: 45701/75127 users processed (60.8%)
# Progress: 45801/75127 users processed (61.0%)
# Progress: 45901/75127 users processed (61.1%)
# Progress: 46001/75127 users processed (61.2%)
# Progress: 46101/75127 users processed (61.4%)
# Progress: 46201/75127 users processed (61.5%)
# Progress: 46301/75127 users processed (61.6%)
# Progress: 46401/75127 users processed (61.8%)
# Progress: 46501/75127 users processed (61.9%)
# Progress: 46601/75127 users processed (62.0%)
# Progress: 46701/75127 users processed (62.2%)
# Progress: 46801/75127 users processed (62.3%)
# Progress: 46901/75127 users processed (62.4%)
# Progress: 47001/75127 users processed (62.6%)
# Progress: 47101/75127 users processed (62.7%)
# Progress: 47201/75127 users processed (62.8%)
# Progress: 47301/75127 users processed (63.0%)
# Progress: 47401/75127 users processed (63.1%)
# Progress: 47501/75127 users processed (63.2%)
# Progress: 47601/75127 users processed (63.4%)
# Progress: 47701/75127 users processed (63.5%)
# Progress: 47801/75127 users processed (63.6%)
# Progress: 47901/75127 users processed (63.8%)
# Progress: 48001/75127 users processed (63.9%)
# Progress: 48101/75127 users processed (64.0%)
# Progress: 48201/75127 users processed (64.2%)
# Progress: 48301/75127 users processed (64.3%)
# Progress: 48401/75127 users processed (64.4%)
# Progress: 48501/75127 users processed (64.6%)
# Progress: 48601/75127 users processed (64.7%)
# Progress: 48701/75127 users processed (64.8%)
# Progress: 48801/75127 users processed (65.0%)
# Progress: 48901/75127 users processed (65.1%)
# Progress: 49001/75127 users processed (65.2%)
# Progress: 49101/75127 users processed (65.4%)
# Progress: 49201/75127 users processed (65.5%)
# Progress: 49301/75127 users processed (65.6%)
# Progress: 49401/75127 users processed (65.8%)
# Progress: 49501/75127 users processed (65.9%)
# Progress: 49601/75127 users processed (66.0%)
# Progress: 49701/75127 users processed (66.2%)
# Progress: 49801/75127 users processed (66.3%)
# Progress: 49901/75127 users processed (66.4%)
# Progress: 50001/75127 users processed (66.6%)
# Progress: 50101/75127 users processed (66.7%)
# Progress: 50201/75127 users processed (66.8%)
# Progress: 50301/75127 users processed (67.0%)
# Progress: 50401/75127 users processed (67.1%)
# Progress: 50501/75127 users processed (67.2%)
# Progress: 50601/75127 users processed (67.4%)
# Progress: 50701/75127 users processed (67.5%)
# Progress: 50801/75127 users processed (67.6%)
# Progress: 50901/75127 users processed (67.8%)
# Progress: 51001/75127 users processed (67.9%)
# Progress: 51101/75127 users processed (68.0%)
# Progress: 51201/75127 users processed (68.2%)
# Progress: 51301/75127 users processed (68.3%)
# Progress: 51401/75127 users processed (68.4%)
# Progress: 51501/75127 users processed (68.6%)
# Progress: 51601/75127 users processed (68.7%)
# Progress: 51701/75127 users processed (68.8%)
# Progress: 51801/75127 users processed (69.0%)
# Progress: 51901/75127 users processed (69.1%)
# Progress: 52001/75127 users processed (69.2%)
# Progress: 52101/75127 users processed (69.4%)
# Progress: 52201/75127 users processed (69.5%)
# Progress: 52301/75127 users processed (69.6%)
# Progress: 52401/75127 users processed (69.7%)
# Progress: 52501/75127 users processed (69.9%)
# Progress: 52601/75127 users processed (70.0%)
# Progress: 52701/75127 users processed (70.1%)
# Progress: 52801/75127 users processed (70.3%)
# Progress: 52901/75127 users processed (70.4%)
# Progress: 53001/75127 users processed (70.5%)
# Progress: 53101/75127 users processed (70.7%)
# Progress: 53201/75127 users processed (70.8%)
# Progress: 53301/75127 users processed (70.9%)
# Progress: 53401/75127 users processed (71.1%)
# Progress: 53501/75127 users processed (71.2%)
# Progress: 53601/75127 users processed (71.3%)
# Progress: 53701/75127 users processed (71.5%)
# Progress: 53801/75127 users processed (71.6%)
# Progress: 53901/75127 users processed (71.7%)
# Progress: 54001/75127 users processed (71.9%)
# Progress: 54101/75127 users processed (72.0%)
# Progress: 54201/75127 users processed (72.1%)
# Progress: 54301/75127 users processed (72.3%)
# Progress: 54401/75127 users processed (72.4%)
# Progress: 54501/75127 users processed (72.5%)
# Progress: 54601/75127 users processed (72.7%)
# Progress: 54701/75127 users processed (72.8%)
# Progress: 54801/75127 users processed (72.9%)
# Progress: 54901/75127 users processed (73.1%)
# Progress: 55001/75127 users processed (73.2%)
# Progress: 55101/75127 users processed (73.3%)
# Progress: 55201/75127 users processed (73.5%)
# Progress: 55301/75127 users processed (73.6%)
# Progress: 55401/75127 users processed (73.7%)
# Progress: 55501/75127 users processed (73.9%)
# Progress: 55601/75127 users processed (74.0%)
# Progress: 55701/75127 users processed (74.1%)
# Progress: 55801/75127 users processed (74.3%)
# Progress: 55901/75127 users processed (74.4%)
# Progress: 56001/75127 users processed (74.5%)
# Progress: 56101/75127 users processed (74.7%)
# Progress: 56201/75127 users processed (74.8%)
# Progress: 56301/75127 users processed (74.9%)
# Progress: 56401/75127 users processed (75.1%)
# Progress: 56501/75127 users processed (75.2%)
# Progress: 56601/75127 users processed (75.3%)
# Progress: 56701/75127 users processed (75.5%)
# Progress: 56801/75127 users processed (75.6%)
# Progress: 56901/75127 users processed (75.7%)
# Progress: 57001/75127 users processed (75.9%)
# Progress: 57101/75127 users processed (76.0%)
# Progress: 57201/75127 users processed (76.1%)
# Progress: 57301/75127 users processed (76.3%)
# Progress: 57401/75127 users processed (76.4%)
# Progress: 57501/75127 users processed (76.5%)
# Progress: 57601/75127 users processed (76.7%)
# Progress: 57701/75127 users processed (76.8%)
# Progress: 57801/75127 users processed (76.9%)
# Progress: 57901/75127 users processed (77.1%)
# Progress: 58001/75127 users processed (77.2%)
# Progress: 58101/75127 users processed (77.3%)
# Progress: 58201/75127 users processed (77.5%)
# Progress: 58301/75127 users processed (77.6%)
# Progress: 58401/75127 users processed (77.7%)
# Progress: 58501/75127 users processed (77.9%)
# Progress: 58601/75127 users processed (78.0%)
# Progress: 58701/75127 users processed (78.1%)
# Progress: 58801/75127 users processed (78.3%)
# Progress: 58901/75127 users processed (78.4%)
# Progress: 59001/75127 users processed (78.5%)
# Progress: 59101/75127 users processed (78.7%)
# Progress: 59201/75127 users processed (78.8%)
# Progress: 59301/75127 users processed (78.9%)
# Progress: 59401/75127 users processed (79.1%)
# Progress: 59501/75127 users processed (79.2%)
# Progress: 59601/75127 users processed (79.3%)
# Progress: 59701/75127 users processed (79.5%)
# Progress: 59801/75127 users processed (79.6%)
# Progress: 59901/75127 users processed (79.7%)
# Progress: 60001/75127 users processed (79.9%)
# Progress: 60101/75127 users processed (80.0%)
# Progress: 60201/75127 users processed (80.1%)
# Progress: 60301/75127 users processed (80.3%)
# Progress: 60401/75127 users processed (80.4%)
# Progress: 60501/75127 users processed (80.5%)
# Progress: 60601/75127 users processed (80.7%)
# Progress: 60701/75127 users processed (80.8%)
# Progress: 60801/75127 users processed (80.9%)
# Progress: 60901/75127 users processed (81.1%)
# Progress: 61001/75127 users processed (81.2%)
# Progress: 61101/75127 users processed (81.3%)
# Progress: 61201/75127 users processed (81.5%)
# Progress: 61301/75127 users processed (81.6%)
# Progress: 61401/75127 users processed (81.7%)
# Progress: 61501/75127 users processed (81.9%)
# Progress: 61601/75127 users processed (82.0%)
# Progress: 61701/75127 users processed (82.1%)
# Progress: 61801/75127 users processed (82.3%)
# Progress: 61901/75127 users processed (82.4%)
# Progress: 62001/75127 users processed (82.5%)
# Progress: 62101/75127 users processed (82.7%)
# Progress: 62201/75127 users processed (82.8%)
# Progress: 62301/75127 users processed (82.9%)
# Progress: 62401/75127 users processed (83.1%)
# Progress: 62501/75127 users processed (83.2%)
# Progress: 62601/75127 users processed (83.3%)
# Progress: 62701/75127 users processed (83.5%)
# Progress: 62801/75127 users processed (83.6%)
# Progress: 62901/75127 users processed (83.7%)
# Progress: 63001/75127 users processed (83.9%)
# Progress: 63101/75127 users processed (84.0%)
# Progress: 63201/75127 users processed (84.1%)
# Progress: 63301/75127 users processed (84.3%)
# Progress: 63401/75127 users processed (84.4%)
# Progress: 63501/75127 users processed (84.5%)
# Progress: 63601/75127 users processed (84.7%)
# Progress: 63701/75127 users processed (84.8%)
# Progress: 63801/75127 users processed (84.9%)
# Progress: 63901/75127 users processed (85.1%)
# Progress: 64001/75127 users processed (85.2%)
# Progress: 64101/75127 users processed (85.3%)
# Progress: 64201/75127 users processed (85.5%)
# Progress: 64301/75127 users processed (85.6%)
# Progress: 64401/75127 users processed (85.7%)
# Progress: 64501/75127 users processed (85.9%)
# Progress: 64601/75127 users processed (86.0%)
# Progress: 64701/75127 users processed (86.1%)
# Progress: 64801/75127 users processed (86.3%)
# Progress: 64901/75127 users processed (86.4%)
# Progress: 65001/75127 users processed (86.5%)
# Progress: 65101/75127 users processed (86.7%)
# Progress: 65201/75127 users processed (86.8%)
# Progress: 65301/75127 users processed (86.9%)
# Progress: 65401/75127 users processed (87.1%)
# Progress: 65501/75127 users processed (87.2%)
# Progress: 65601/75127 users processed (87.3%)
# Progress: 65701/75127 users processed (87.5%)
# Progress: 65801/75127 users processed (87.6%)
# Progress: 65901/75127 users processed (87.7%)
# Progress: 66001/75127 users processed (87.9%)
# Progress: 66101/75127 users processed (88.0%)
# Progress: 66201/75127 users processed (88.1%)
# Progress: 66301/75127 users processed (88.3%)
# Progress: 66401/75127 users processed (88.4%)
# Progress: 66501/75127 users processed (88.5%)
# Progress: 66601/75127 users processed (88.7%)
# Progress: 66701/75127 users processed (88.8%)
# Progress: 66801/75127 users processed (88.9%)
# Progress: 66901/75127 users processed (89.1%)
# Progress: 67001/75127 users processed (89.2%)
# Progress: 67101/75127 users processed (89.3%)
# Progress: 67201/75127 users processed (89.4%)
# Progress: 67301/75127 users processed (89.6%)
# Progress: 67401/75127 users processed (89.7%)
# Progress: 67501/75127 users processed (89.8%)
# Progress: 67601/75127 users processed (90.0%)
# Progress: 67701/75127 users processed (90.1%)
# Progress: 67801/75127 users processed (90.2%)
# Progress: 67901/75127 users processed (90.4%)
# Progress: 68001/75127 users processed (90.5%)
# Progress: 68101/75127 users processed (90.6%)
# Progress: 68201/75127 users processed (90.8%)
# Progress: 68301/75127 users processed (90.9%)
# Progress: 68401/75127 users processed (91.0%)
# Progress: 68501/75127 users processed (91.2%)
# Progress: 68601/75127 users processed (91.3%)
# Progress: 68701/75127 users processed (91.4%)
# Progress: 68801/75127 users processed (91.6%)
# Progress: 68901/75127 users processed (91.7%)
# Progress: 69001/75127 users processed (91.8%)
# Progress: 69101/75127 users processed (92.0%)
# Progress: 69201/75127 users processed (92.1%)
# Progress: 69301/75127 users processed (92.2%)
# Progress: 69401/75127 users processed (92.4%)
# Progress: 69501/75127 users processed (92.5%)
# Progress: 69601/75127 users processed (92.6%)
# Progress: 69701/75127 users processed (92.8%)
# Progress: 69801/75127 users processed (92.9%)
# Progress: 69901/75127 users processed (93.0%)
# Progress: 70001/75127 users processed (93.2%)
# Progress: 70101/75127 users processed (93.3%)
# Progress: 70201/75127 users processed (93.4%)
# Progress: 70301/75127 users processed (93.6%)
# Progress: 70401/75127 users processed (93.7%)
# Progress: 70501/75127 users processed (93.8%)
# Progress: 70601/75127 users processed (94.0%)
# Progress: 70701/75127 users processed (94.1%)
# Progress: 70801/75127 users processed (94.2%)
# Progress: 70901/75127 users processed (94.4%)
# Progress: 71001/75127 users processed (94.5%)
# Progress: 71101/75127 users processed (94.6%)
# Progress: 71201/75127 users processed (94.8%)
# Progress: 71301/75127 users processed (94.9%)
# Progress: 71401/75127 users processed (95.0%)
# Progress: 71501/75127 users processed (95.2%)
# Progress: 71601/75127 users processed (95.3%)
# Progress: 71701/75127 users processed (95.4%)
# Progress: 71801/75127 users processed (95.6%)
# Progress: 71901/75127 users processed (95.7%)
# Progress: 72001/75127 users processed (95.8%)
# Progress: 72101/75127 users processed (96.0%)
# Progress: 72201/75127 users processed (96.1%)
# Progress: 72301/75127 users processed (96.2%)
# Progress: 72401/75127 users processed (96.4%)
# Progress: 72501/75127 users processed (96.5%)
# Progress: 72601/75127 users processed (96.6%)
# Progress: 72701/75127 users processed (96.8%)
# Progress: 72801/75127 users processed (96.9%)
# Progress: 72901/75127 users processed (97.0%)
# Progress: 73001/75127 users processed (97.2%)
# Progress: 73101/75127 users processed (97.3%)
# Progress: 73201/75127 users processed (97.4%)
# Progress: 73301/75127 users processed (97.6%)
# Progress: 73401/75127 users processed (97.7%)
# Progress: 73501/75127 users processed (97.8%)
# Progress: 73601/75127 users processed (98.0%)
# Progress: 73701/75127 users processed (98.1%)
# Progress: 73801/75127 users processed (98.2%)
# Progress: 73901/75127 users processed (98.4%)
# Progress: 74001/75127 users processed (98.5%)
# Progress: 74101/75127 users processed (98.6%)
# Progress: 74201/75127 users processed (98.8%)
# Progress: 74301/75127 users processed (98.9%)
# Progress: 74401/75127 users processed (99.0%)
# Progress: 74501/75127 users processed (99.2%)
# Progress: 74601/75127 users processed (99.3%)
# Progress: 74701/75127 users processed (99.4%)
# Progress: 74801/75127 users processed (99.6%)
# Progress: 74901/75127 users processed (99.7%)
# Progress: 75001/75127 users processed (99.8%)
# Progress: 75101/75127 users processed (100.0%)
# Progress: 75127/75127 users processed (100.0%)
# Completed generating recommendations for 75127 March users
# Calculating MAP@10 score...
# MAP@10 score for March validation: 0.04079090881919163
# Cell ended!

# %% [markdown]
# ## 11. April Predictions

# %%
print("Generating April predictions...")

april_predictions = {}
submission_users = submission['user_id'].tolist()

print(f"Generating recommendations for {len(submission_users)} submission users...")

debug_users = submission_users[:3]

total_users = len(submission_users)
for i, user in enumerate(submission_users):
    # Print progress every 100 users
    if i % 100 == 0 or i == total_users - 1:
        progress = (i + 1) / total_users * 100
        print(f"Progress: {i+1}/{total_users} users processed ({progress:.1f}%)")
        sys.stdout.flush()
        
    try:
        # Enable debug for sample users
        debug_mode = user in debug_users
        
        recommendations = generate_recommendations(
            user,
            full_history_with_details,
            april_candidates,
            april_popularity,
            april_city_popularity,
            full_frequency,
            full_day_prefs,
            april_day_patterns,
            debug=debug_mode
        )
        april_predictions[user] = recommendations
    except Exception as e:
        print(f"Error for user {user}: {e}")
        april_predictions[user] = []

print(f"Completed generating recommendations for {len(april_predictions)} submission users")
cell_end()
# Out:
# Generating April predictions...
# Generating recommendations for 53825 submission users...
# Progress: 1/53825 users processed (0.0%)
# Debug for user user_99065:
#   City: Алматы
#   Top genres: ['мюзикл/фэнтези/комедия']
#   Top types: ['film']
#   Monthly frequency: 1.00
#   Day preferences: {'Monday': np.float64(1.0)}
#   Top 3 recommended events:
#     event_3852: 4.2110 (Genre: драма, Type: film)
#     event_3719: 4.1985 (Genre: комедия, Type: film)
#     event_2392: 4.1973 (Genre: фантастика/боевик/драма, Type: film)
# Debug for user user_72897:
#   City: Алматы
#   Top genres: ['балет']
#   Top types: ['performance']
#   Monthly frequency: 1.00
#   Day preferences: {'Wednesday': np.float64(1.0)}
#   Top 3 recommended events:
#     event_825: 10.4271 (Genre: балет, Type: performance)
#     event_682: 10.3899 (Genre: балет, Type: performance)
#     event_3929: 10.3896 (Genre: балет, Type: performance)
# Debug for user user_88085:
#   City: Астана
#   Top genres: ['сказка']
#   Top types: ['performance']
#   Monthly frequency: 1.00
#   Day preferences: {'Wednesday': np.float64(1.0)}
#   Top 3 recommended events:
#     event_1855: 10.4167 (Genre: сказка, Type: performance)
#     event_1518: 10.4000 (Genre: сказка, Type: performance)
#     event_920: 10.3091 (Genre: сказка, Type: performance)
# Progress: 101/53825 users processed (0.2%)
# Progress: 201/53825 users processed (0.4%)
# Progress: 301/53825 users processed (0.6%)
# Progress: 401/53825 users processed (0.7%)
# Progress: 501/53825 users processed (0.9%)
# Progress: 601/53825 users processed (1.1%)
# Progress: 701/53825 users processed (1.3%)
# Progress: 801/53825 users processed (1.5%)
# Progress: 901/53825 users processed (1.7%)
# Progress: 1001/53825 users processed (1.9%)
# Progress: 1101/53825 users processed (2.0%)
# Progress: 1201/53825 users processed (2.2%)
# Progress: 1301/53825 users processed (2.4%)
# Progress: 1401/53825 users processed (2.6%)
# Progress: 1501/53825 users processed (2.8%)
# Progress: 1601/53825 users processed (3.0%)
# Progress: 1701/53825 users processed (3.2%)
# Progress: 1801/53825 users processed (3.3%)
# Progress: 1901/53825 users processed (3.5%)
# Progress: 2001/53825 users processed (3.7%)
# Progress: 2101/53825 users processed (3.9%)
# Progress: 2201/53825 users processed (4.1%)
# Progress: 2301/53825 users processed (4.3%)
# Progress: 2401/53825 users processed (4.5%)
# Progress: 2501/53825 users processed (4.6%)
# Progress: 2601/53825 users processed (4.8%)
# Progress: 2701/53825 users processed (5.0%)
# Progress: 2801/53825 users processed (5.2%)
# Progress: 2901/53825 users processed (5.4%)
# Progress: 3001/53825 users processed (5.6%)
# Progress: 3101/53825 users processed (5.8%)
# Progress: 3201/53825 users processed (5.9%)
# Progress: 3301/53825 users processed (6.1%)
# Progress: 3401/53825 users processed (6.3%)
# Progress: 3501/53825 users processed (6.5%)
# Progress: 3601/53825 users processed (6.7%)
# Progress: 3701/53825 users processed (6.9%)
# Progress: 3801/53825 users processed (7.1%)
# Progress: 3901/53825 users processed (7.2%)
# Progress: 4001/53825 users processed (7.4%)
# Progress: 4101/53825 users processed (7.6%)
# Progress: 4201/53825 users processed (7.8%)
# Progress: 4301/53825 users processed (8.0%)
# Progress: 4401/53825 users processed (8.2%)
# Progress: 4501/53825 users processed (8.4%)
# Progress: 4601/53825 users processed (8.5%)
# Progress: 4701/53825 users processed (8.7%)
# Progress: 4801/53825 users processed (8.9%)
# Progress: 4901/53825 users processed (9.1%)
# Progress: 5001/53825 users processed (9.3%)
# Progress: 5101/53825 users processed (9.5%)
# Progress: 5201/53825 users processed (9.7%)
# Progress: 5301/53825 users processed (9.8%)
# Progress: 5401/53825 users processed (10.0%)
# Progress: 5501/53825 users processed (10.2%)
# Progress: 5601/53825 users processed (10.4%)
# Progress: 5701/53825 users processed (10.6%)
# Progress: 5801/53825 users processed (10.8%)
# Progress: 5901/53825 users processed (11.0%)
# Progress: 6001/53825 users processed (11.1%)
# Progress: 6101/53825 users processed (11.3%)
# Progress: 6201/53825 users processed (11.5%)
# Progress: 6301/53825 users processed (11.7%)
# Progress: 6401/53825 users processed (11.9%)
# Progress: 6501/53825 users processed (12.1%)
# Progress: 6601/53825 users processed (12.3%)
# Progress: 6701/53825 users processed (12.4%)
# Progress: 6801/53825 users processed (12.6%)
# Progress: 6901/53825 users processed (12.8%)
# Progress: 7001/53825 users processed (13.0%)
# Progress: 7101/53825 users processed (13.2%)
# Progress: 7201/53825 users processed (13.4%)
# Progress: 7301/53825 users processed (13.6%)
# Progress: 7401/53825 users processed (13.8%)
# Progress: 7501/53825 users processed (13.9%)
# Progress: 7601/53825 users processed (14.1%)
# Progress: 7701/53825 users processed (14.3%)
# Progress: 7801/53825 users processed (14.5%)
# Progress: 7901/53825 users processed (14.7%)
# Progress: 8001/53825 users processed (14.9%)
# Progress: 8101/53825 users processed (15.1%)
# Progress: 8201/53825 users processed (15.2%)
# Progress: 8301/53825 users processed (15.4%)
# Progress: 8401/53825 users processed (15.6%)
# Progress: 8501/53825 users processed (15.8%)
# Progress: 8601/53825 users processed (16.0%)
# Progress: 8701/53825 users processed (16.2%)
# Progress: 8801/53825 users processed (16.4%)
# Progress: 8901/53825 users processed (16.5%)
# Progress: 9001/53825 users processed (16.7%)
# Progress: 9101/53825 users processed (16.9%)
# Progress: 9201/53825 users processed (17.1%)
# Progress: 9301/53825 users processed (17.3%)
# Progress: 9401/53825 users processed (17.5%)
# Progress: 9501/53825 users processed (17.7%)
# Progress: 9601/53825 users processed (17.8%)
# Progress: 9701/53825 users processed (18.0%)
# Progress: 9801/53825 users processed (18.2%)
# Progress: 9901/53825 users processed (18.4%)
# Progress: 10001/53825 users processed (18.6%)
# Progress: 10101/53825 users processed (18.8%)
# Progress: 10201/53825 users processed (19.0%)
# Progress: 10301/53825 users processed (19.1%)
# Progress: 10401/53825 users processed (19.3%)
# Progress: 10501/53825 users processed (19.5%)
# Progress: 10601/53825 users processed (19.7%)
# Progress: 10701/53825 users processed (19.9%)
# Progress: 10801/53825 users processed (20.1%)
# Progress: 10901/53825 users processed (20.3%)
# Progress: 11001/53825 users processed (20.4%)
# Progress: 11101/53825 users processed (20.6%)
# Progress: 11201/53825 users processed (20.8%)
# Progress: 11301/53825 users processed (21.0%)
# Progress: 11401/53825 users processed (21.2%)
# Progress: 11501/53825 users processed (21.4%)
# Progress: 11601/53825 users processed (21.6%)
# Progress: 11701/53825 users processed (21.7%)
# Progress: 11801/53825 users processed (21.9%)
# Progress: 11901/53825 users processed (22.1%)
# Progress: 12001/53825 users processed (22.3%)
# Progress: 12101/53825 users processed (22.5%)
# Progress: 12201/53825 users processed (22.7%)
# Progress: 12301/53825 users processed (22.9%)
# Progress: 12401/53825 users processed (23.0%)
# Progress: 12501/53825 users processed (23.2%)
# Progress: 12601/53825 users processed (23.4%)
# Progress: 12701/53825 users processed (23.6%)
# Progress: 12801/53825 users processed (23.8%)
# Progress: 12901/53825 users processed (24.0%)
# Progress: 13001/53825 users processed (24.2%)
# Progress: 13101/53825 users processed (24.3%)
# Progress: 13201/53825 users processed (24.5%)
# Progress: 13301/53825 users processed (24.7%)
# Progress: 13401/53825 users processed (24.9%)
# Progress: 13501/53825 users processed (25.1%)
# Progress: 13601/53825 users processed (25.3%)
# Progress: 13701/53825 users processed (25.5%)
# Progress: 13801/53825 users processed (25.6%)
# Progress: 13901/53825 users processed (25.8%)
# Progress: 14001/53825 users processed (26.0%)
# Progress: 14101/53825 users processed (26.2%)
# Progress: 14201/53825 users processed (26.4%)
# Progress: 14301/53825 users processed (26.6%)
# Progress: 14401/53825 users processed (26.8%)
# Progress: 14501/53825 users processed (26.9%)
# Progress: 14601/53825 users processed (27.1%)
# Progress: 14701/53825 users processed (27.3%)
# Progress: 14801/53825 users processed (27.5%)
# Progress: 14901/53825 users processed (27.7%)
# Progress: 15001/53825 users processed (27.9%)
# Progress: 15101/53825 users processed (28.1%)
# Progress: 15201/53825 users processed (28.2%)
# Progress: 15301/53825 users processed (28.4%)
# Progress: 15401/53825 users processed (28.6%)
# Progress: 15501/53825 users processed (28.8%)
# Progress: 15601/53825 users processed (29.0%)
# Progress: 15701/53825 users processed (29.2%)
# Progress: 15801/53825 users processed (29.4%)
# Progress: 15901/53825 users processed (29.5%)
# Progress: 16001/53825 users processed (29.7%)
# Progress: 16101/53825 users processed (29.9%)
# Progress: 16201/53825 users processed (30.1%)
# Progress: 16301/53825 users processed (30.3%)
# Progress: 16401/53825 users processed (30.5%)
# Progress: 16501/53825 users processed (30.7%)
# Progress: 16601/53825 users processed (30.8%)
# Progress: 16701/53825 users processed (31.0%)
# Progress: 16801/53825 users processed (31.2%)
# Progress: 16901/53825 users processed (31.4%)
# Progress: 17001/53825 users processed (31.6%)
# Progress: 17101/53825 users processed (31.8%)
# Progress: 17201/53825 users processed (32.0%)
# Progress: 17301/53825 users processed (32.1%)
# Progress: 17401/53825 users processed (32.3%)
# Progress: 17501/53825 users processed (32.5%)
# Progress: 17601/53825 users processed (32.7%)
# Progress: 17701/53825 users processed (32.9%)
# Progress: 17801/53825 users processed (33.1%)
# Progress: 17901/53825 users processed (33.3%)
# Progress: 18001/53825 users processed (33.4%)
# Progress: 18101/53825 users processed (33.6%)
# Progress: 18201/53825 users processed (33.8%)
# Progress: 18301/53825 users processed (34.0%)
# Progress: 18401/53825 users processed (34.2%)
# Progress: 18501/53825 users processed (34.4%)
# Progress: 18601/53825 users processed (34.6%)
# Progress: 18701/53825 users processed (34.7%)
# Progress: 18801/53825 users processed (34.9%)
# Progress: 18901/53825 users processed (35.1%)
# Progress: 19001/53825 users processed (35.3%)
# Progress: 19101/53825 users processed (35.5%)
# Progress: 19201/53825 users processed (35.7%)
# Progress: 19301/53825 users processed (35.9%)
# Progress: 19401/53825 users processed (36.0%)
# Progress: 19501/53825 users processed (36.2%)
# Progress: 19601/53825 users processed (36.4%)
# Progress: 19701/53825 users processed (36.6%)
# Progress: 19801/53825 users processed (36.8%)
# Progress: 19901/53825 users processed (37.0%)
# Progress: 20001/53825 users processed (37.2%)
# Progress: 20101/53825 users processed (37.3%)
# Progress: 20201/53825 users processed (37.5%)
# Progress: 20301/53825 users processed (37.7%)
# Progress: 20401/53825 users processed (37.9%)
# Progress: 20501/53825 users processed (38.1%)
# Progress: 20601/53825 users processed (38.3%)
# Progress: 20701/53825 users processed (38.5%)
# Progress: 20801/53825 users processed (38.6%)
# Progress: 20901/53825 users processed (38.8%)
# Progress: 21001/53825 users processed (39.0%)
# Progress: 21101/53825 users processed (39.2%)
# Progress: 21201/53825 users processed (39.4%)
# Progress: 21301/53825 users processed (39.6%)
# Progress: 21401/53825 users processed (39.8%)
# Progress: 21501/53825 users processed (39.9%)
# Progress: 21601/53825 users processed (40.1%)
# Progress: 21701/53825 users processed (40.3%)
# Progress: 21801/53825 users processed (40.5%)
# Progress: 21901/53825 users processed (40.7%)
# Progress: 22001/53825 users processed (40.9%)
# Progress: 22101/53825 users processed (41.1%)
# Progress: 22201/53825 users processed (41.2%)
# Progress: 22301/53825 users processed (41.4%)
# Progress: 22401/53825 users processed (41.6%)
# Progress: 22501/53825 users processed (41.8%)
# Progress: 22601/53825 users processed (42.0%)
# Progress: 22701/53825 users processed (42.2%)
# Progress: 22801/53825 users processed (42.4%)
# Progress: 22901/53825 users processed (42.5%)
# Progress: 23001/53825 users processed (42.7%)
# Progress: 23101/53825 users processed (42.9%)
# Progress: 23201/53825 users processed (43.1%)
# Progress: 23301/53825 users processed (43.3%)
# Progress: 23401/53825 users processed (43.5%)
# Progress: 23501/53825 users processed (43.7%)
# Progress: 23601/53825 users processed (43.8%)
# Progress: 23701/53825 users processed (44.0%)
# Progress: 23801/53825 users processed (44.2%)
# Progress: 23901/53825 users processed (44.4%)
# Progress: 24001/53825 users processed (44.6%)
# Progress: 24101/53825 users processed (44.8%)
# Progress: 24201/53825 users processed (45.0%)
# Progress: 24301/53825 users processed (45.1%)
# Progress: 24401/53825 users processed (45.3%)
# Progress: 24501/53825 users processed (45.5%)
# Progress: 24601/53825 users processed (45.7%)
# Progress: 24701/53825 users processed (45.9%)
# Progress: 24801/53825 users processed (46.1%)
# Progress: 24901/53825 users processed (46.3%)
# Progress: 25001/53825 users processed (46.4%)
# Progress: 25101/53825 users processed (46.6%)
# Progress: 25201/53825 users processed (46.8%)
# Progress: 25301/53825 users processed (47.0%)
# Progress: 25401/53825 users processed (47.2%)
# Progress: 25501/53825 users processed (47.4%)
# Progress: 25601/53825 users processed (47.6%)
# Progress: 25701/53825 users processed (47.7%)
# Progress: 25801/53825 users processed (47.9%)
# Progress: 25901/53825 users processed (48.1%)
# Progress: 26001/53825 users processed (48.3%)
# Progress: 26101/53825 users processed (48.5%)
# Progress: 26201/53825 users processed (48.7%)
# Progress: 26301/53825 users processed (48.9%)
# Progress: 26401/53825 users processed (49.0%)
# Progress: 26501/53825 users processed (49.2%)
# Progress: 26601/53825 users processed (49.4%)
# Progress: 26701/53825 users processed (49.6%)
# Progress: 26801/53825 users processed (49.8%)
# Progress: 26901/53825 users processed (50.0%)
# Progress: 27001/53825 users processed (50.2%)
# Progress: 27101/53825 users processed (50.4%)
# Progress: 27201/53825 users processed (50.5%)
# Progress: 27301/53825 users processed (50.7%)
# Progress: 27401/53825 users processed (50.9%)
# Progress: 27501/53825 users processed (51.1%)
# Progress: 27601/53825 users processed (51.3%)
# Progress: 27701/53825 users processed (51.5%)
# Progress: 27801/53825 users processed (51.7%)
# Progress: 27901/53825 users processed (51.8%)
# Progress: 28001/53825 users processed (52.0%)
# Progress: 28101/53825 users processed (52.2%)
# Progress: 28201/53825 users processed (52.4%)
# Progress: 28301/53825 users processed (52.6%)
# Progress: 28401/53825 users processed (52.8%)
# Progress: 28501/53825 users processed (53.0%)
# Progress: 28601/53825 users processed (53.1%)
# Progress: 28701/53825 users processed (53.3%)
# Progress: 28801/53825 users processed (53.5%)
# Progress: 28901/53825 users processed (53.7%)
# Progress: 29001/53825 users processed (53.9%)
# Progress: 29101/53825 users processed (54.1%)
# Progress: 29201/53825 users processed (54.3%)
# Progress: 29301/53825 users processed (54.4%)
# Progress: 29401/53825 users processed (54.6%)
# Progress: 29501/53825 users processed (54.8%)
# Progress: 29601/53825 users processed (55.0%)
# Progress: 29701/53825 users processed (55.2%)
# Progress: 29801/53825 users processed (55.4%)
# Progress: 29901/53825 users processed (55.6%)
# Progress: 30001/53825 users processed (55.7%)
# Progress: 30101/53825 users processed (55.9%)
# Progress: 30201/53825 users processed (56.1%)
# Progress: 30301/53825 users processed (56.3%)
# Progress: 30401/53825 users processed (56.5%)
# Progress: 30501/53825 users processed (56.7%)
# Progress: 30601/53825 users processed (56.9%)
# Progress: 30701/53825 users processed (57.0%)
# Progress: 30801/53825 users processed (57.2%)
# Progress: 30901/53825 users processed (57.4%)
# Progress: 31001/53825 users processed (57.6%)
# Progress: 31101/53825 users processed (57.8%)
# Progress: 31201/53825 users processed (58.0%)
# Progress: 31301/53825 users processed (58.2%)
# Progress: 31401/53825 users processed (58.3%)
# Progress: 31501/53825 users processed (58.5%)
# Progress: 31601/53825 users processed (58.7%)
# Progress: 31701/53825 users processed (58.9%)
# Progress: 31801/53825 users processed (59.1%)
# Progress: 31901/53825 users processed (59.3%)
# Progress: 32001/53825 users processed (59.5%)
# Progress: 32101/53825 users processed (59.6%)
# Progress: 32201/53825 users processed (59.8%)
# Progress: 32301/53825 users processed (60.0%)
# Progress: 32401/53825 users processed (60.2%)
# Progress: 32501/53825 users processed (60.4%)
# Progress: 32601/53825 users processed (60.6%)
# Progress: 32701/53825 users processed (60.8%)
# Progress: 32801/53825 users processed (60.9%)
# Progress: 32901/53825 users processed (61.1%)
# Progress: 33001/53825 users processed (61.3%)
# Progress: 33101/53825 users processed (61.5%)
# Progress: 33201/53825 users processed (61.7%)
# Progress: 33301/53825 users processed (61.9%)
# Progress: 33401/53825 users processed (62.1%)
# Progress: 33501/53825 users processed (62.2%)
# Progress: 33601/53825 users processed (62.4%)
# Progress: 33701/53825 users processed (62.6%)
# Progress: 33801/53825 users processed (62.8%)
# Progress: 33901/53825 users processed (63.0%)
# Progress: 34001/53825 users processed (63.2%)
# Progress: 34101/53825 users processed (63.4%)
# Progress: 34201/53825 users processed (63.5%)
# Progress: 34301/53825 users processed (63.7%)
# Progress: 34401/53825 users processed (63.9%)
# Progress: 34501/53825 users processed (64.1%)
# Progress: 34601/53825 users processed (64.3%)
# Progress: 34701/53825 users processed (64.5%)
# Progress: 34801/53825 users processed (64.7%)
# Progress: 34901/53825 users processed (64.8%)
# Progress: 35001/53825 users processed (65.0%)
# Progress: 35101/53825 users processed (65.2%)
# Progress: 35201/53825 users processed (65.4%)
# Progress: 35301/53825 users processed (65.6%)
# Progress: 35401/53825 users processed (65.8%)
# Progress: 35501/53825 users processed (66.0%)
# Progress: 35601/53825 users processed (66.1%)
# Progress: 35701/53825 users processed (66.3%)
# Progress: 35801/53825 users processed (66.5%)
# Progress: 35901/53825 users processed (66.7%)
# Progress: 36001/53825 users processed (66.9%)
# Progress: 36101/53825 users processed (67.1%)
# Progress: 36201/53825 users processed (67.3%)
# Progress: 36301/53825 users processed (67.4%)
# Progress: 36401/53825 users processed (67.6%)
# Progress: 36501/53825 users processed (67.8%)
# Progress: 36601/53825 users processed (68.0%)
# Progress: 36701/53825 users processed (68.2%)
# Progress: 36801/53825 users processed (68.4%)
# Progress: 36901/53825 users processed (68.6%)
# Progress: 37001/53825 users processed (68.7%)
# Progress: 37101/53825 users processed (68.9%)
# Progress: 37201/53825 users processed (69.1%)
# Progress: 37301/53825 users processed (69.3%)
# Progress: 37401/53825 users processed (69.5%)
# Progress: 37501/53825 users processed (69.7%)
# Progress: 37601/53825 users processed (69.9%)
# Progress: 37701/53825 users processed (70.0%)
# Progress: 37801/53825 users processed (70.2%)
# Progress: 37901/53825 users processed (70.4%)
# Progress: 38001/53825 users processed (70.6%)
# Progress: 38101/53825 users processed (70.8%)
# Progress: 38201/53825 users processed (71.0%)
# Progress: 38301/53825 users processed (71.2%)
# Progress: 38401/53825 users processed (71.3%)
# Progress: 38501/53825 users processed (71.5%)
# Progress: 38601/53825 users processed (71.7%)
# Progress: 38701/53825 users processed (71.9%)
# Progress: 38801/53825 users processed (72.1%)
# Progress: 38901/53825 users processed (72.3%)
# Progress: 39001/53825 users processed (72.5%)
# Progress: 39101/53825 users processed (72.6%)
# Progress: 39201/53825 users processed (72.8%)
# Progress: 39301/53825 users processed (73.0%)
# Progress: 39401/53825 users processed (73.2%)
# Progress: 39501/53825 users processed (73.4%)
# Progress: 39601/53825 users processed (73.6%)
# Progress: 39701/53825 users processed (73.8%)
# Progress: 39801/53825 users processed (73.9%)
# Progress: 39901/53825 users processed (74.1%)
# Progress: 40001/53825 users processed (74.3%)
# Progress: 40101/53825 users processed (74.5%)
# Progress: 40201/53825 users processed (74.7%)
# Progress: 40301/53825 users processed (74.9%)
# Progress: 40401/53825 users processed (75.1%)
# Progress: 40501/53825 users processed (75.2%)
# Progress: 40601/53825 users processed (75.4%)
# Progress: 40701/53825 users processed (75.6%)
# Progress: 40801/53825 users processed (75.8%)
# Progress: 40901/53825 users processed (76.0%)
# Progress: 41001/53825 users processed (76.2%)
# Progress: 41101/53825 users processed (76.4%)
# Progress: 41201/53825 users processed (76.5%)
# Progress: 41301/53825 users processed (76.7%)
# Progress: 41401/53825 users processed (76.9%)
# Progress: 41501/53825 users processed (77.1%)
# Progress: 41601/53825 users processed (77.3%)
# Progress: 41701/53825 users processed (77.5%)
# Progress: 41801/53825 users processed (77.7%)
# Progress: 41901/53825 users processed (77.8%)
# Progress: 42001/53825 users processed (78.0%)
# Progress: 42101/53825 users processed (78.2%)
# Progress: 42201/53825 users processed (78.4%)
# Progress: 42301/53825 users processed (78.6%)
# Progress: 42401/53825 users processed (78.8%)
# Progress: 42501/53825 users processed (79.0%)
# Progress: 42601/53825 users processed (79.1%)
# Progress: 42701/53825 users processed (79.3%)
# Progress: 42801/53825 users processed (79.5%)
# Progress: 42901/53825 users processed (79.7%)
# Progress: 43001/53825 users processed (79.9%)
# Progress: 43101/53825 users processed (80.1%)
# Progress: 43201/53825 users processed (80.3%)
# Progress: 43301/53825 users processed (80.4%)
# Progress: 43401/53825 users processed (80.6%)
# Progress: 43501/53825 users processed (80.8%)
# Progress: 43601/53825 users processed (81.0%)
# Progress: 43701/53825 users processed (81.2%)
# Progress: 43801/53825 users processed (81.4%)
# Progress: 43901/53825 users processed (81.6%)
# Progress: 44001/53825 users processed (81.7%)
# Progress: 44101/53825 users processed (81.9%)
# Progress: 44201/53825 users processed (82.1%)
# Progress: 44301/53825 users processed (82.3%)
# Progress: 44401/53825 users processed (82.5%)
# Progress: 44501/53825 users processed (82.7%)
# Progress: 44601/53825 users processed (82.9%)
# Progress: 44701/53825 users processed (83.0%)
# Progress: 44801/53825 users processed (83.2%)
# Progress: 44901/53825 users processed (83.4%)
# Progress: 45001/53825 users processed (83.6%)
# Progress: 45101/53825 users processed (83.8%)
# Progress: 45201/53825 users processed (84.0%)
# Progress: 45301/53825 users processed (84.2%)
# Progress: 45401/53825 users processed (84.3%)
# Progress: 45501/53825 users processed (84.5%)
# Progress: 45601/53825 users processed (84.7%)
# Progress: 45701/53825 users processed (84.9%)
# Progress: 45801/53825 users processed (85.1%)
# Progress: 45901/53825 users processed (85.3%)
# Progress: 46001/53825 users processed (85.5%)
# Progress: 46101/53825 users processed (85.6%)
# Progress: 46201/53825 users processed (85.8%)
# Progress: 46301/53825 users processed (86.0%)
# Progress: 46401/53825 users processed (86.2%)
# Progress: 46501/53825 users processed (86.4%)
# Progress: 46601/53825 users processed (86.6%)
# Progress: 46701/53825 users processed (86.8%)
# Progress: 46801/53825 users processed (87.0%)
# Progress: 46901/53825 users processed (87.1%)
# Progress: 47001/53825 users processed (87.3%)
# Progress: 47101/53825 users processed (87.5%)
# Progress: 47201/53825 users processed (87.7%)
# Progress: 47301/53825 users processed (87.9%)
# Progress: 47401/53825 users processed (88.1%)
# Progress: 47501/53825 users processed (88.3%)
# Progress: 47601/53825 users processed (88.4%)
# Progress: 47701/53825 users processed (88.6%)
# Progress: 47801/53825 users processed (88.8%)
# Progress: 47901/53825 users processed (89.0%)
# Progress: 48001/53825 users processed (89.2%)
# Progress: 48101/53825 users processed (89.4%)
# Progress: 48201/53825 users processed (89.6%)
# Progress: 48301/53825 users processed (89.7%)
# Progress: 48401/53825 users processed (89.9%)
# Progress: 48501/53825 users processed (90.1%)
# Progress: 48601/53825 users processed (90.3%)
# Progress: 48701/53825 users processed (90.5%)
# Progress: 48801/53825 users processed (90.7%)
# Progress: 48901/53825 users processed (90.9%)
# Progress: 49001/53825 users processed (91.0%)
# Progress: 49101/53825 users processed (91.2%)
# Progress: 49201/53825 users processed (91.4%)
# Progress: 49301/53825 users processed (91.6%)
# Progress: 49401/53825 users processed (91.8%)
# Progress: 49501/53825 users processed (92.0%)
# Progress: 49601/53825 users processed (92.2%)
# Progress: 49701/53825 users processed (92.3%)
# Progress: 49801/53825 users processed (92.5%)
# Progress: 49901/53825 users processed (92.7%)
# Progress: 50001/53825 users processed (92.9%)
# Progress: 50101/53825 users processed (93.1%)
# Progress: 50201/53825 users processed (93.3%)
# Progress: 50301/53825 users processed (93.5%)
# Progress: 50401/53825 users processed (93.6%)
# Progress: 50501/53825 users processed (93.8%)
# Progress: 50601/53825 users processed (94.0%)
# Progress: 50701/53825 users processed (94.2%)
# Progress: 50801/53825 users processed (94.4%)
# Progress: 50901/53825 users processed (94.6%)
# Progress: 51001/53825 users processed (94.8%)
# Progress: 51101/53825 users processed (94.9%)
# Progress: 51201/53825 users processed (95.1%)
# Progress: 51301/53825 users processed (95.3%)
# Progress: 51401/53825 users processed (95.5%)
# Progress: 51501/53825 users processed (95.7%)
# Progress: 51601/53825 users processed (95.9%)
# Progress: 51701/53825 users processed (96.1%)
# Progress: 51801/53825 users processed (96.2%)
# Progress: 51901/53825 users processed (96.4%)
# Progress: 52001/53825 users processed (96.6%)
# Progress: 52101/53825 users processed (96.8%)
# Progress: 52201/53825 users processed (97.0%)
# Progress: 52301/53825 users processed (97.2%)
# Progress: 52401/53825 users processed (97.4%)
# Progress: 52501/53825 users processed (97.5%)
# Progress: 52601/53825 users processed (97.7%)
# Progress: 52701/53825 users processed (97.9%)
# Progress: 52801/53825 users processed (98.1%)
# Progress: 52901/53825 users processed (98.3%)
# Progress: 53001/53825 users processed (98.5%)
# Progress: 53101/53825 users processed (98.7%)
# Progress: 53201/53825 users processed (98.8%)
# Progress: 53301/53825 users processed (99.0%)
# Progress: 53401/53825 users processed (99.2%)
# Progress: 53501/53825 users processed (99.4%)
# Progress: 53601/53825 users processed (99.6%)
# Progress: 53701/53825 users processed (99.8%)
# Progress: 53801/53825 users processed (100.0%)
# Progress: 53825/53825 users processed (100.0%)
# Completed generating recommendations for 53825 submission users
# Cell ended!

# %% [markdown]
# ## 12. Create Submission File

# %%
print("Creating submission file...")
result = []
for user in submission_users:
    items = april_predictions.get(user, [])
    item_str = ','.join(items)
    result.append({'user_id': user, 'item_ids': item_str})

result_df = pd.DataFrame(result)

result_df.to_csv('ticketon_result.csv', index=False, quoting=1)
print("Submission file created: ticketon_result.csv")

print("\nFirst 5 rows of submission file:")
print(result_df.head())
cell_end()
# Out:
# Creating submission file...
# Submission file created: ticketon_result.csv
#
# First 5 rows of submission file:
#        user_id                                           item_ids
# 0   user_99065  event_3852,event_3719,event_2392,event_4457,ev...
# 1   user_72897  event_825,event_682,event_3929,event_183,event...
# 2   user_88085  event_1855,event_1518,event_920,event_57,event...
# 3  user_108651  event_4425,event_254,event_2548,event_3719,eve...
# 4   user_28053  event_3928,event_3939,event_2885,event_3852,ev...
# Cell ended!

# %% [markdown]
# ## 13. Model Summary

# %%
print("\nRecommendation Model Summary:")
print("-" * 50)
print("This model incorporates several key behavioral patterns:")
print("1. User preferences for event genres and types")
print("2. Day-of-week attendance patterns")
print("3. User's attendance frequency (events per month)")
print("4. City-based preference weighting")
print("5. Popularity fallbacks for cold-start users")
print("-" * 50)
print(f"MAP@10 on March validation data: {march_map}")
print("Full results saved to: ticketon_result.csv")
print("\nProgram execution completed successfully!")
cell_end()
# Out:
# Recommendation Model Summary:
# --------------------------------------------------
# This model incorporates several key behavioral patterns:
# 1. User preferences for event genres and types
# 2. Day-of-week attendance patterns
# 3. User's attendance frequency (events per month)
# 4. City-based preference weighting
# 5. Popularity fallbacks for cold-start users
# --------------------------------------------------
# MAP@10 on March validation data: 0.04079090881919163
# Full results saved to: ticketon_result.csv
#
# Program execution completed successfully!
# Cell ended!
